# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/processed/ipl_cleaned.csv")
# Out:
# C:\Users\palag\AppData\Local\Temp\ipykernel_20332\2281376924.py:1: DtypeWarning: Columns (0: season, 1: result_margin) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/processed/ipl_cleaned.csv")

# %%
df.head()
# Out:
#    match_id   season        date       city                  venue  \
# 0    335982  2007/08  2008-04-18  Bangalore  M Chinnaswamy Stadium
# 1    335982  2007/08  2008-04-18  Bangalore  M Chinnaswamy Stadium
# 2    335982  2007/08  2008-04-18  Bangalore  M Chinnaswamy Stadium
# 3    335982  2007/08  2008-04-18  Bangalore  M Chinnaswamy Stadium
# 4    335982  2007/08  2008-04-18  Bangalore  M Chinnaswamy Stadium
#
#                          team1                  team2  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders
# 1  Royal Challengers Bangalore  Kolkata Knight Riders
# 2  Royal Challengers Bangalore  Kolkata Knight Riders
# 3  Royal Challengers Bangalore  Kolkata Knight Riders
# 4  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner toss_decision                 winner  ...  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders  ...
# 1  Royal Challengers Bangalore         field  Kolkata Knight Riders  ...
# ...

# %%
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 278205
# Columns : 33

# %%
print(df.columns.tolist())
# Out:
# ['match_id', 'season', 'date', 'city', 'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result', 'result_margin', 'player_of_match', 'inning', 'batting_team', 'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker', 'runs_scored', 'extras', 'current_score', 'wickets_down', 'balls_remaining', 'wickets_remaining', 'current_run_rate', 'required_run_rate', 'target_score', 'wicket_kind', 'player_out', 'fielder']

# %%
df.describe()
# Out:
# c:\Users\palag\OneDrive\Desktop\IPL-Complete-Analytics\venv\Lib\site-packages\pandas\core\nanops.py:1028: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#            match_id         inning           over           ball  \
# count  2.782050e+05  278205.000000  278205.000000  278205.000000
# mean   9.422687e+05       1.482914       9.193839       3.626434
# std    3.817198e+05       0.502571       5.681511       1.816767
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.483530e+05       1.000000       4.000000       2.000000
# 50%    1.082601e+06       1.000000       9.000000       4.000000
# 75%    1.304049e+06       2.000000      14.000000       5.000000
# max    1.485779e+06       6.000000      19.000000      11.000000
#
#          runs_scored         extras  current_score   wickets_down  \
# count  278205.000000  278205.000000  278205.000000  278205.000000
# ...

# %%
df.isnull().sum()
# Out:
# match_id                  0
# season                    0
# date                      0
# city                  12397
# venue                     0
# team1                     0
# team2                     0
# toss_winner               0
# toss_decision             0
# winner                 4702
# result                    0
# result_margin             0
# player_of_match         806
# inning                    0
# batting_team              0
# bowling_team              0
# over                      0
# ball                      0
# batter                    0
# bowler                    0
# non_striker               0
# runs_scored               0
# extras                    0
# current_score             0
# wickets_down              0
# balls_remaining           0
# wickets_remaining         0
# current_run_rate          0
# required_run_rate    144302
# target_score         144302
# wicket_kind          264382
# player_out           264382
# fielder              268192
# ...

# %%
missing = df.isnull().sum().sort_values(ascending=False)

missing.head(10)
# Out:
# fielder              268192
# player_out           264382
# wicket_kind          264382
# target_score         144302
# required_run_rate    144302
# city                  12397
# winner                 4702
# player_of_match         806
# match_id                  0
# toss_decision             0
# dtype: int64

# %%
df.dtypes
# Out:
# match_id               int64
# season                object
# date                     str
# city                     str
# venue                    str
# team1                    str
# team2                    str
# toss_winner              str
# toss_decision            str
# winner                   str
# result                   str
# result_margin         object
# player_of_match          str
# inning                 int64
# batting_team             str
# bowling_team             str
# over                   int64
# ball                   int64
# batter                   str
# bowler                   str
# non_striker              str
# runs_scored            int64
# extras                 int64
# current_score          int64
# wickets_down           int64
# balls_remaining        int64
# wickets_remaining      int64
# current_run_rate     float64
# required_run_rate    float64
# target_score         float64
# wicket_kind              str
# player_out               str
# ...

# %%
df.memory_usage(deep=True)
# Out:
# Index                     132
# match_id              2225640
# season               11535658
# date                 16414095
# city                 15369211
# venue                21553923
# team1                18652520
# team2                18560542
# toss_winner          18571074
# toss_decision        14830018
# winner               18462395
# result               15190467
# result_margin        12877262
# player_of_match      16277894
# inning                2225640
# batting_team         18605066
# bowling_team         18607996
# over                  2225640
# ball                  2225640
# batter               16265117
# bowler               16359995
# non_striker          16268283
# runs_scored           2225640
# extras                2225640
# current_score         2225640
# wickets_down          2225640
# balls_remaining       2225640
# wickets_remaining     2225640
# current_run_rate      2225640
# required_run_rate     2225640
# target_score          2225640
# ...

# %%
df.nunique()
# Out:
# match_id             1169
# season                 21
# date                  885
# city                   37
# venue                  59
# team1                  19
# team2                  19
# toss_winner            19
# toss_decision           2
# winner                 19
# result                  2
# result_margin         161
# player_of_match       308
# inning                  6
# batting_team           19
# bowling_team           19
# over                   20
# ball                   11
# batter                703
# bowler                550
# non_striker           692
# runs_scored             7
# extras                  7
# current_score         283
# wickets_down           11
# balls_remaining       122
# wickets_remaining      11
# current_run_rate     1546
# required_run_rate    3074
# target_score          175
# wicket_kind            10
# player_out            655
# fielder               641
# dtype: int64

# %%
df["batting_team"].value_counts()
# Out:
# batting_team
# Mumbai Indians                 33323
# Kolkata Knight Riders          30895
# Chennai Super Kings            30395
# Royal Challengers Bangalore    28205
# Rajasthan Royals               27922
# Sunrisers Hyderabad            23442
# Kings XI Punjab                22646
# Delhi Daredevils               18786
# Delhi Capitals                 12615
# Deccan Chargers                 9034
# Punjab Kings                    8865
# Gujarat Titans                  7331
# Lucknow Super Giants            7144
# Pune Warriors                   5443
# Gujarat Lions                   3566
# Royal Challengers Bengaluru     3531
# Rising Pune Supergiant          1900
# Kochi Tuskers Kerala            1582
# Rising Pune Supergiants         1580
# Name: count, dtype: int64

# %%
print(df.columns.tolist())
# Out:
# ['match_id', 'season', 'date', 'city', 'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result', 'result_margin', 'player_of_match', 'inning', 'batting_team', 'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker', 'runs_scored', 'extras', 'current_score', 'wickets_down', 'balls_remaining', 'wickets_remaining', 'current_run_rate', 'required_run_rate', 'target_score', 'wicket_kind', 'player_out', 'fielder']

# %%
import os

print("Current working directory:")
print(os.getcwd())

print("\nReports folder exists:")
print(os.path.exists("../reports"))

print("\nAbsolute reports path:")
print(os.path.abspath("../reports"))
# Out:
# Current working directory:
# c:\Users\palag\OneDrive\Desktop\IPL-Complete-Analytics\notebooks
#
# Reports folder exists:
# False
#
# Absolute reports path:
# c:\Users\palag\OneDrive\Desktop\IPL-Complete-Analytics\reports

# %%
import os

try:
    with open("../reports/test.txt", "w") as f:
        f.write("Hello")
    print("✅ Successfully wrote test.txt")
except Exception as e:
    print("❌ Error:", e)
# Out:
# ❌ Error: [Errno 2] No such file or directory: '../reports/test.txt'

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [1, 4, 9])

try:
    plt.savefig("../reports/test_plot.png")
    print("✅ Plot saved successfully")
except Exception as e:
    print("❌ Error:", e)

plt.show()
# Out:
# ❌ Error: [Errno 2] No such file or directory: '../reports/test_plot.png'
